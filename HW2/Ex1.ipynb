# %% [markdown]
# ### Задание 1
# Сделайте приоритезацию гипотез из предыдущего урока с помощью ICE
#
# ### Задание 2.
# Составьте шаблон дизайна эксперимента для гипотезы, которая набрала больше всего баллов в практическом задании предыдущего урока

# %% [markdown]
# #### Задание 1
#
# 1. Изменение дизайна приветственного экрана       Impact  5           Confidence  5       Ease   7    ICE score   175
# 2. Оптимизация рекомендаций                       Impact  6           Confidence  6       Ease   3    ICE score   108
# 3. Изменение сиситемы фильтрации товаров          Impact  3           Confidence  5       Ease   9    ICE score   135

# %% [markdown]
# #### Задание 2
#
# 1. Гипотеза изменения приветственнного экрана. Если изменить акцент внимания посетителей на лучшие предложения и убрать отвелаюие внимание сслыки - это увеличит количество переходов на страницы маркетинговых акций и конкретных товаров на 20%. Что приведет к росту конверсии посетителей в покупателей на 3%.
# Тестируем на всех пользовтаелях.
# Метрика - количество переходов со стартовой страницы на страницу конкретного товара.
#
# 2. Гипотеза оптимизации  рекоменндаций. Внедрение системы персональных рекомендаций в зависимости от предпочтений простомтра определенных групп товаров для авторизованых пользоватлей. Точно настроенные рекомендации для конкретного покупателя повысят частоту посеения сайта клиентом на 20% и увеличат количетсво покупок в рекоменндоанных категориях на 30%.
# Тестируем авторизованнх пользовтаелей совершивших хотя бы одну покупку и участвуюих в программах лояльности.
# Метрика - Частота посещения приложения клиентом.
#
# 3. Изменение сиситемы фильтрации товаров. Улучшиение системы подбора товаров увеличит среднее время нахождения потребителя на сайте и количество просмотреных карточек товара.
# Тестируем на всех категориях посетителей.
# Метрика - количество переходов на странницу конкретного товара из списка отсортированныых товаров.
