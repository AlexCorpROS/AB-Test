# %% [markdown]
# Продакт на главной mail.ru решил протестировать в рекомендательной ленте контента вместо карточек со статьями видеоплеер с короткими видео. Нынешний таймспент на юзера в день в среднем равен 25 минут, а стандартная ошибка (SD) равна 156. Мы предполагаем, что в новой версии таймспент на юзера в день изменится на 10%. Средний трафик 20000 человек в день. Посчитайте сколько дней необходимо держать эксперимент при alpha = 5% и beta = 20% .
#
# Наша продуктовая команда в ecommerce магазине планирует запустить тест, направленный на ускорение загрузки сайта. Одна из основных метрик bounce rate в GA = 40%. Мы предполагаем, что при оптимизации сайта она изменится минимум на 20%.Средний трафик 4000 человек в день. Посчитайте сколько нам нужно дней держать эксперимент при alpha = 5% и beta = 20%. Калькуляторы, которые могут помочь в решение задачь: https://www.evanmiller.org/ab-testing/sample-size.html и https://www.statulator.com/SampleSize/ss2M.html

# %% [markdown]
# #### Задача 1
# Исходные данные для расчета в калькуляторе.
# Mean of the Reference Group = 25
# Mean of the Test Group = 27.5
# Standard Deviation = 156
# Desired Power = 0.8
# Level of Significance = 0.05
#
# Для теста потребуется выборка 61124 пользователя для каждой группы или 122248 пользовталей для обеих групп. Так как средний раффик у нас 20 000 пользователей в день, то округляя нам потребуется тест на 6-7 дней.

# %% [markdown]
# #### Задача 2
# Исходные данные для расчета в калькуляторе.
# Baseline conversion rate - 40%
# Minimum Detectable Effect - 20%
# alpha = 5%
# beta = 20%
#
# Для теста каждой группы потребуется 592 пользователя или всего  1184 пользовтаеля для двух групп. Так как среднний трафик в день 4000 человек, то для теста потребуется один день.
